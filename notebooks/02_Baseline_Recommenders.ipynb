# %% [markdown]
# # Moving to Modeling: Popularity Baselines

# %%
import sys
import os
import matplotlib.pyplot as plt

# Add the parent directory (project root) to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from src.data_utils import movies_rating

# %%
from src.recommender import recommend_high_quality

# %%
reliable_movies = recommend_high_quality(movies_rating, 30000, 10)

print(reliable_movies[["title", "avg_rating", "num_rating"]])
# Out:
#                               title  avg_rating  num_rating
# 0  Shawshank Redemption, The (1994)         4.4       80530
# 1        Usual Suspects, The (1995)         4.3       55075
# 2             Godfather, The (1972)         4.3       52093
# 3    Godfather: Part II, The (1974)         4.3       33996
# 4               Pulp Fiction (1994)         4.2       79000
# 5  Silence of the Lambs, The (1991)         4.2       73486
# 6                Matrix, The (1999)         4.2       72197
# 7           Schindler's List (1993)         4.2       59937
# 8                 Fight Club (1999)         4.2       58376
# 9           Dark Knight, The (2008)         4.2       41187

# %%
plt.figure(figsize=(10, 6))
bins = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]
plt.hist(movies_rating["avg_rating"], bins=bins, edgecolor="black")
plt.title("Distribution of Average Ratings")
plt.xlabel("Average Rating", fontsize=12)
plt.ylabel("Frequency(count)", fontsize=12)
plt.grid(True, alpha=0.3, linestyle="--")
plt.xticks([0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.figure(figsize=(10, 6))
#       2 bins = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]
#       3 plt.hist(movies_rating["avg_rating"], bins=bins, edgecolor="black")
#
# NameError: name 'plt' is not defined
